# %% [markdown]
# # 1. Spotify Dataset
# The "data.csv" file contains more than 160.000 songs collected from Spotify Web API. The dataset is from Spotify and contains 169k songs from the year 1921 to year 2020. Each year got
# top 100 songs.
#
# Primary:
#
# * id (Id of track generated by Spotify)
# * Numerical:
# * acousticness (Ranges from 0 to 1)
# * danceability (Ranges from 0 to 1)
# * energy (Ranges from 0 to 1)
# * duration_ms (Integer typically ranging from 200k to 300k)
# * instrumentalness (Ranges from 0 to 1)
# * valence (Ranges from 0 to 1)
# * popularity (Ranges from 0 to 100)
# * tempo (Float typically ranging from 50 to 150)
# * liveness (Ranges from 0 to 1)
# * loudness (Float typically ranging from -60 to 0)
# * speechiness (Ranges from 0 to 1)
# * year (Ranges from 1921 to 2020)
#
# Dummy:
# * mode (0 = Minor, 1 = Major)
# * explicit (0 = No explicit content, 1 = Explicit content)
#
# Categorical:
# * key (All keys on octave encoded as values ranging from 0 to 11, starting on C as 0, C# as 1 and so on…)
# * artists (List of artists mentioned)
# * release_date (Date of release mostly in yyyy-mm-dd format, however precision of date may vary)
# * name (Name of the song)
#
# More Information:
#
# Some of the key attributes present in each event in the data are:
# * key — The estimated overall key of the track. Integers map to pitches using standard Pitch Class notation. Ex: 0 = C, 1 = C♯/D♭, 2 = D, and so on. If no key was detected, the value is -1.
# * Mode — Mode indicates the modality (major or minor) of a track, the type of scale from which its melodic content is derived. Major is represented by 1 and minor is 0.
# * Acoustiness — A confidence measure from 0.0 to 1.0 of whether the track is acoustic. 1.0 represents high confidence the track is acoustic.
# * Danceability — Danceability describes how suitable a track is for dancing based on a combination of musical elements including tempo, rhythm stability, beat strength, and overall regularity. A value of 0.0 is least danceable and 1.0 is the most danceable.
# * Energy — Energy is a measure from 0.0 to 1.0 and represents a perceptual measure of intensity and activity. Typically, energetic tracks feel fast, loud, and noisy.
# * Instrumentalness — Predicts whether a track contains no vocals. The closer the instrumentalness value is to 1.0, the greater likelihood the track contains no vocal content.
# * Loudness — The overall loudness of a track in decibels (dB). Values typical range between -60 and 0 dB.
# * Valence — A measure from 0.0 to 1.0 describing the musical positiveness conveyed by a track. Tracks with high valence sound more positive.
# * Tempo — The overall estimated tempo of a track in beats per minute (BPM).
# * Popularity — The popularity of the track. The value will be between 0 and 100, with 100 being the most popular.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# For validation
from sklearn.model_selection import train_test_split as split

# For transformations and predictions
from scipy.optimize import curve_fit
from sklearn.preprocessing import FunctionTransformer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.compose import ColumnTransformer

# For models
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier

# For boosting
from sklearn.ensemble import AdaBoostClassifier

# For scoring
from sklearn.metrics import mean_squared_error as mse
from sklearn.metrics import accuracy_score

from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score
from sklearn.metrics import classification_report

# %% [markdown]
# # 2. Import data and cleaning

# %%
## Import the dataset
df = pd.read_csv('data.csv')

## Drop unnecessary columns 
df = df.drop(["explicit", "id", "mode", "name", "release_date"], axis=1)

# Drop duplicates (there's no null values)
df = df[~df.duplicated()==1]

# %% [markdown]
# There are 14 features and one target variable which is 'popularity'.

# %%
df.tail()
# Out:
#         acousticness                             artists  danceability  \
# 169904        0.1730              ['DripReport', 'Tyga']         0.875
# 169905        0.0167  ['Leon Bridges', 'Terrace Martin']         0.719
# 169906        0.5380               ['Kygo', 'Oh Wonder']         0.514
# 169907        0.0714       ['Cash Cash', 'Andy Grammer']         0.646
# 169908        0.1090                  ['Ingrid Andress']         0.512
#
#         duration_ms  energy  instrumentalness  key  liveness  loudness  \
# 169904       163800   0.443          0.000032    1    0.0891    -7.461
# 169905       167468   0.385          0.031300    8    0.1110   -10.907
# 169906       180700   0.539          0.002330    7    0.1080    -9.332
# 169907       167308   0.761          0.000000    1    0.2220    -2.557
# 169908       214787   0.428          0.000000    0    0.1050    -7.387
#
#         popularity  speechiness    tempo  valence  year
# 169904          75       0.1430  100.012    0.306  2020
# 169905          64       0.0403  128.000    0.270  2020
# 169906          70       0.1050  123.700    0.153  2020
# 169907          70       0.0385  129.916    0.472  2020
# 169908          65       0.0271   80.588    0.366  2020

# %% [markdown]
# ## 2.1 Adding a new column
# I chose these labels based partially on concentrations found in the data, but mostly the choices were made based on intuition. Below is the code to set up and inspect the new column specifying the labels.

# %%
classified = df.copy()
classified['pop_rating'] = ''

for i, row in classified.iterrows():
    score = 'unpopular'
    if (row.popularity > 50) & (row.popularity < 75):
        score = 'medium'
    elif row.popularity >= 75:
        score = 'popular'
    classified.at[i, 'pop_rating'] = score

# %% [markdown]
# The different classes in the classified dataset exhibit a high level of imbalance. This needs to be accounted for in order to ensure the models perform as well as possible. Here's a visualization of the disparity.

# %%
fig, ax = plt.subplots(1,1, figsize=(8,5))
_ = sns.countplot(x='pop_rating', data=classified)
_ = plt.xlabel('Ratings', fontsize=14)
_ = plt.title('Counts', fontsize=14)

# %% [markdown]
# # 3 EDA - Correlations
# ### 3.1 Finding the correlation between all of the numerical features.
# We can now examine the rest of the features and see how they correlate with each other, in particular how they correlate with the popularity column.
# A heatmap is a graphical representation of data where each value of a matrix is represented as a color.

# %%
numeric_columns = df.columns[df.dtypes != 'object']
numeric_df = pd.DataFrame(data=df, columns=numeric_columns, index=df.index)

corr = np.abs(numeric_df.corr())
fig, ax = plt.subplots(figsize=(8, 8))
cmap = sns.color_palette("Greens")
sns.heatmap(corr, cmap=cmap, square=True)
plt.title('Correlation between numerical features: abs values')
plt.show()

# %% [markdown]
# ### 3.2 The most linear correlated features to POPULARITY
# The following code creates the correlation matrix between all the features we are examining and our y-variable.
# As we can see down below, the 'popularity' have a strong correlation with 'year', 'loudness' and 'energy'...

# %%
corr = numeric_df.corr()[['popularity']].sort_values(by='popularity', ascending=False)
plt.figure(figsize=(8, 12))
heatmap = sns.heatmap(corr, annot=True, cmap='Greens')
heatmap.set_title('The most linear correlated features to POPULARITY', fontdict={'fontsize':18}, pad=16);

# %% [markdown]
# ### 3.3 Year
# * From the heatmap above, the correlation between popularity and year is strong, which makes sense, since popularity is mostly new music.
# * The year attribute is linearly close to the popularity target (corr = 0.88)
# * Due to the very high linear correlation between the year and the popularity, this feature will be excluded from our models.
#
# As expected, popularity is highly correlated with the year released. This makes sense as the Spotify algorithm which makes this decision generates its “popularity” metric by not just how many streams a song receives, but also how recent those streams are.

# %%
fig, ax = plt.subplots(figsize=(15, 4))
ax = df.groupby('year')['popularity'].mean().plot(color='green')
ax.set_title('Mean Popularity over the years', c='green', weight='bold')
ax.set_ylabel('Mean Popularity', weight='bold')
ax.set_xlabel('Year', weight='bold')
ax.set_xticks(range(1920, 2021, 5))
plt.show()

# %%
def regress_plot(x='', y='', data=None, xlab='', ylab='', titl=''):
    '''Plots a scatterplot with a regression line
    using given inputs'''
    data = data.groupby(x)[y].mean().to_frame().reset_index()
    fig, ax = plt.subplots(figsize=(10,6))
    _ = sns.regplot(x=x, y=y, data=data, scatter_kws={'color': 'g', "s": 10}, line_kws={'color':'black'} )
    _ = plt.xlabel(xlab, fontsize=12)
    _ = plt.ylabel(ylab, fontsize=12)
    _ = plt.title(titl, fontsize=14, c='green')
    _ = plt.ylim(-3, 103)
    plt.show()

# %% [markdown]
# ### 3.4 Energy - (ranges from 0 to 1)
# * Measure the intensity and activity, energetic track feels faster, louder and noisier.
# * It seems that there is a releativly strong linear correlation of 0.497 correlation to the target.
# * From the correlation heatmap, the best predictor seemed to be energy.
#
# Energy also seems to influence a song’s popularity. Many popular songs are energetic, though not necessarily dance songs. Because the correlation here is not too high, low energy songs do have some potential to be more popular.

# %%
regress_plot(x='energy', y='popularity', data=df, xlab='Energy', ylab='Mean Popularity', titl='Mean Popularity vs. Energy')

# %% [markdown]
# ### 3.5 Loudness  - float typically ranging from (-60 to 0)
# The regressor clearly shows there is a positive correlation, and the data tends to narrow towards the top, but overall the observations are quite scattered. It's not a very strong fit.
# Loudness and energy are highly correlated. This makes some sense as energy is definitely influenced by the volume at which the music is being played.

# %%
regress_plot(x='loudness', y='popularity', data=df, xlab='Loudness', ylab='Mean Popularity', titl='Mean Popularity vs. Loudness')

# %% [markdown]
# ### 3.6 Danceability - (ranges from 0 to 1)
# * Danceability- measure if the song is dancable based on the combination of tempo rythm and beat strength
# * Danceability seems to have a normal distribution between 0-1
# * the majoirity of Danceability values is between 0.2-0.8 with mean 0.53

# %%
regress_plot(x='danceability', y='popularity', data=df, xlab='Danceability', ylab='Mean Popularity', titl='Mean Popularity vs. Danceability')

# %% [markdown]
# ### 3.7 Tempo - (float typically ranging from 50 to 150)

# %%
regress_plot(x='tempo', y='popularity', data=df, xlab='Tempo', ylab='Mean Popularity', titl='Mean Popularity vs. Tempo')

# %% [markdown]
# ### 3.8 Acousticness
# Acoustiness seems to be uncorrelated with popularity. Most popular songs today have either electronic or electric instruments in them. It is very rare that a piece of music played by a chamber orchestra or purely acoustic band becomes immensely popular

# %%
regress_plot(x='acousticness', y='popularity', data=df, xlab='Acousticness', ylab='Mean Popularity', titl='Mean Popularity vs. Acousticness')

# %% [markdown]
# ### 3.9 In general
# Unpopular songs and popular songs can have many similarities, and all popular songs can have many differences. The purpose of this project is to see if an algorithm can sort out these differences and similarities better than a human could.
#
# Thus, from this data, it would be better for an artist to create a high energy song with either electric instruments or electronic songs to have the best chance of generating the most popularity.
#
# We need to design an ML Model that can predict the Popularity based on the features available.
# The chart shows five features are with negative correlation and seven features with positive correlation.

# %% [markdown]
# # 4. **Pre-Processing**
# * Import data with relevant columns only
# * Remove duplicates
# * Split data to train & test

# %%
## Import the dataset
df = pd.read_csv('data.csv')

# %% [markdown]
# ### 4.1 Data Cleaning - (Data Imputation)

# %% [markdown]
# #### 4.1.1 Drop Duplicates

# %%
# Remove duplicated
df = df[~df.duplicated()==1]

# %% [markdown]
# #### 4.1.2 Convert Duration

# %%
# Transform milliseconds to minutes
df["duration_mins"] = df["duration_ms"]/60000
df.drop(columns="duration_ms", inplace=True)

# %%
#Remove the Square Brackets from the artists

df["artists"]=df["artists"].str.replace("[", "")
df["artists"]=df["artists"].str.replace("]", "")
df["artists"]=df["artists"].str.replace("'", "")

# %% [markdown]
# ## Prepare

# %%
data = df.copy()

# data.loc[((df.popularity >= 0) & (df.popularity <= 10)), "popularity_level" ] = 1
# data.loc[((df.popularity > 10) & (df.popularity <= 20)), "popularity_level" ] = 2
# data.loc[((df.popularity > 20) & (df.popularity <= 30)), "popularity_level" ] = 3
# data.loc[((df.popularity > 30) & (df.popularity <= 40)), "popularity_level" ] = 4
# data.loc[((df.popularity > 40) & (df.popularity <= 50)), "popularity_level" ] = 5
# data.loc[((df.popularity > 50) & (df.popularity <= 60)), "popularity_level" ] = 6
# data.loc[((df.popularity > 60) & (df.popularity <= 70)), "popularity_level" ] = 7
# data.loc[((df.popularity > 70) & (df.popularity <= 80)), "popularity_level" ] = 8
# data.loc[((df.popularity > 80) & (df.popularity <= 90)), "popularity_level" ] = 9
# data.loc[((df.popularity > 90) & (df.popularity <= 100)), "popularity_level" ] = 10

data.loc[((df.popularity >= 0) & (df.popularity <= 20)), "popularity_level" ] = 1
data.loc[((df.popularity > 20) & (df.popularity <= 40)), "popularity_level" ] = 2
data.loc[((df.popularity > 40) & (df.popularity <= 60)), "popularity_level" ] = 3
data.loc[((df.popularity > 60) & (df.popularity <= 80)), "popularity_level" ] = 4
data.loc[((df.popularity > 80) & (df.popularity <= 100)), "popularity_level" ] = 5

data["popularity_level"] = data["popularity_level"].astype("int")

data
# Out:
#         acousticness                             artists  danceability  \
# 0             0.9950                     Carl Woitschach         0.708
# 1             0.9940  Robert Schumann, Vladimir Horowitz         0.379
# 2             0.6040                 Seweryn Goszczyński         0.749
# 3             0.9950                    Francisco Canaro         0.781
# 4             0.9900  Frédéric Chopin, Vladimir Horowitz         0.210
# ...              ...                                 ...           ...
# 169904        0.1730                    DripReport, Tyga         0.875
# 169905        0.0167        Leon Bridges, Terrace Martin         0.719
# 169906        0.5380                     Kygo, Oh Wonder         0.514
# 169907        0.0714             Cash Cash, Andy Grammer         0.646
# 169908        0.1090                      Ingrid Andress         0.512
#
#         energy  explicit                      id  instrumentalness  key  \
# 0       0.1950         0  6KbQ3uYMLKb5jDxLF7wYDD          0.563000   10
# 1       0.0135         0  6KuQTIu1KoTTkLXKrwlLPV          0.901000    8
# 2       0.2200         0  6L63VW0PibdM1HDSBoqnoM          0.000000    5
# 3       0.1300         0  6M94FkXd15sOAOQYRnWPN8          0.887000    1
# 4       0.2040         0  6N6tiFZ9vLTSOIxkj8qKrd          0.908000   11
# ...        ...       ...                     ...               ...  ...
# 169904  0.4430         1  4KppkflX7I3vJQk7urOJaS          0.000032    1
# 169905  0.3850         0  1ehhGlTvjtHo2e4xJFB0SZ          0.031300    8
# 169906  0.5390         0  52eycxprLhK3lPcRLbQiVk          0.002330    7
# 169907  0.7610         0  3wYOGJYD31sLRmBgCvWxa4          0.000000    1
# 169908  0.4280         0  60RFlt48hm0l4Fu0JoccOl          0.000000    0
#
#         liveness  loudness  mode  \
# 0         0.1510   -12.428     1
# 1         0.0763   -28.454     1
# 2         0.1190   -19.924     0
# 3         0.1110   -14.734     0
# 4         0.0980   -16.829     1
# ...          ...       ...   ...
# 169904    0.0891    -7.461     1
# 169905    0.1110   -10.907     1
# 169906    0.1080    -9.332     1
# 169907    0.2220    -2.557     1
# 169908    0.1050    -7.387     1
#
#                                                  name  popularity  \
# 0                         Singende Bataillone 1. Teil           0
# 1            Fantasiestücke, Op. 111: Più tosto lento           0
# 2                      Chapter 1.18 - Zamek kaniowski           0
# 3       Bebamos Juntos - Instrumental (Remasterizado)           0
# 4         Polonaise-Fantaisie in A-Flat Major, Op. 61           1
# ...                                               ...         ...
# 169904                  Skechers (feat. Tyga) - Remix          75
# 169905                 Sweeter (feat. Terrace Martin)          64
# 169906                               How Would I Know          70
# 169907                                    I Found You          70
# 169908                          More Hearts Than Mine          65
#
#        release_date  speechiness    tempo  valence  year  duration_mins  \
# 0              1928       0.0506  118.469   0.7790  1928       2.644133
# 1              1928       0.0462   83.972   0.0767  1928       4.702217
# 2              1928       0.9290  107.177   0.8800  1928       1.738333
# 3        1928-09-25       0.0926  108.003   0.7200  1928       3.012667
# 4              1928       0.0424   62.149   0.0693  1928      11.462217
# ...             ...          ...      ...      ...   ...            ...
# 169904   2020-05-15       0.1430  100.012   0.3060  2020       2.730000
# 169905   2020-06-08       0.0403  128.000   0.2700  2020       2.791133
# 169906   2020-05-29       0.1050  123.700   0.1530  2020       3.011667
# 169907   2020-02-28       0.0385  129.916   0.4720  2020       2.788467
# 169908   2020-03-27       0.0271   80.588   0.3660  2020       3.579783
#
#         popularity_level
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 169904                 4
# 169905                 4
# 169906                 4
# 169907                 4
# 169908                 4
#
# [169909 rows x 20 columns]

# %% [markdown]
# ### 4.2 Example cases

# %%
artists = ['Drake', 'Lady Gaga', 'Taylor Swift', 'The Weeknd']

# Create a list of indices corresponding to the artists above
# The first comprehension creates a list of lists, the second flattens it into one
to_drop = [data[data.artists == name].index.tolist() for name in artists]
to_drop = [ind for sub in to_drop for ind in sub]

# Gather the test cases
df_x = data.copy()
cases = df_x[df_x.index.isin(to_drop)]

# Remove the test cases from data
data.drop(to_drop, inplace=True)

## Drop unnecessary columns 
data = data.drop(["popularity", "explicit", "id", "mode", "name", "release_date", "artists"], axis=1)

data
# Out:
#         acousticness  danceability  energy  instrumentalness  key  liveness  \
# 0             0.9950         0.708  0.1950          0.563000   10    0.1510
# 1             0.9940         0.379  0.0135          0.901000    8    0.0763
# 2             0.6040         0.749  0.2200          0.000000    5    0.1190
# 3             0.9950         0.781  0.1300          0.887000    1    0.1110
# 4             0.9900         0.210  0.2040          0.908000   11    0.0980
# ...              ...           ...     ...               ...  ...       ...
# 169904        0.1730         0.875  0.4430          0.000032    1    0.0891
# 169905        0.0167         0.719  0.3850          0.031300    8    0.1110
# 169906        0.5380         0.514  0.5390          0.002330    7    0.1080
# 169907        0.0714         0.646  0.7610          0.000000    1    0.2220
# 169908        0.1090         0.512  0.4280          0.000000    0    0.1050
#
#         loudness  speechiness    tempo  valence  year  duration_mins  \
# 0        -12.428       0.0506  118.469   0.7790  1928       2.644133
# 1        -28.454       0.0462   83.972   0.0767  1928       4.702217
# 2        -19.924       0.9290  107.177   0.8800  1928       1.738333
# 3        -14.734       0.0926  108.003   0.7200  1928       3.012667
# 4        -16.829       0.0424   62.149   0.0693  1928      11.462217
# ...          ...          ...      ...      ...   ...            ...
# 169904    -7.461       0.1430  100.012   0.3060  2020       2.730000
# 169905   -10.907       0.0403  128.000   0.2700  2020       2.791133
# 169906    -9.332       0.1050  123.700   0.1530  2020       3.011667
# 169907    -2.557       0.0385  129.916   0.4720  2020       2.788467
# 169908    -7.387       0.0271   80.588   0.3660  2020       3.579783
#
#         popularity_level
# 0                      1
# 1                      1
# 2                      1
# 3                      1
# 4                      1
# ...                  ...
# 169904                 4
# 169905                 4
# 169906                 4
# 169907                 4
# 169908                 4
#
# [169415 rows x 13 columns]

# %%
# Prepare data for prediction
y = data['popularity_level']
X = data.drop(columns=['popularity_level'])
X_train, X_test, y_train, y_test = split(X, y, test_size = 0.25, random_state = 42)

# %% [markdown]
# ### 4.2 Feature Transformations
# Steps followed in Feature Transformation are:
# * Object data of the artists with some numerical indicator that identify the artist.
# * Eliminate Zero values from tempo columns and replace it
# * Standardizing Instrumental Criteria with numeric values
# * Using OneHotEncoder from SKlearn to create dummies
# * Minmax Scaling for relevant features
# * Target Scaling for Popularity Column
#
#
# * A one hot encoding is a representation of categorical variables as binary vectors.
# * This first requires that the categorical values be mapped to integer values.
# * Then, each integer value is represented as a binary vector that is all zero values except the index of the integer, which is marked with a 1.
# * we would like to give the network more expressive power to learn a probability-like number for each possible label value. This can help in both making the problem easier for the network to model. When a one hot encoding is used for the output variable, it may offer a more nuanced set of predictions than a single label.

# %%
# Transform features by scaling specific features to a given range
ctr = ColumnTransformer([('minmax', MinMaxScaler(), ['year', 'tempo', 'duration_mins']),
                        ('categorical', OneHotEncoder(), ['key'])],
                       remainder='passthrough')

# %%
ctr .fit(X_train)
X_train_preprocessed = ctr .transform(X_train)
X_test_preprocessed = ctr .transform(X_test)

# %% [markdown]
# # 5. Modeling
#
# * Decision Tree
# * Nearest Neighbors Classifier
# * Logistic Regression
# * Adaboost Classifier
# * SVM ??? RandomForestClassifier

# %%
results = []

def run_model(model, alg_name):
   # build the model on training data
   model.fit(X_train, y_train)
 
   # make predictions for test data
   y_pred = model.predict(X_test)
   # calculate the accuracy score
   accuracy =  accuracy_score(y_test, y_pred)
   cm = confusion_matrix(y_test, y_pred)
   scoresDT3 = cross_val_score(model, X_test, y_test, cv=6)
   Cr = classification_report(y_test, y_pred)
   results.append((alg_name, accuracy, model))
   print("Model: ", alg_name)
   print("Accuracy on Test Set for {} = {:.2f}\n".format(alg_name,accuracy))
   print(Cr)
   print("{}: CrossVal Accuracy Mean: {:.2f} and Standard Deviation: {:.2f} \n".format(alg_name,scoresDT3.mean(), scoresDT3.std()))

# %% [markdown]
# ### 5.1 Decision Tree Classifier
# To start off simple, I first ran a basic decision tree classifier. This only generates one tree so it's not computationally intensive, but it's also susceptible to overfitting.

# %%
model = DecisionTreeClassifier()
run_model(model, "Decision Tree")
# Out:
# Model:  Decision Tree
# Accuracy on Test Set for Decision Tree = 0.65
#
#               precision    recall  f1-score   support
#
#            1       0.87      0.86      0.86     13304
#            2       0.58      0.57      0.57     13062
#            3       0.56      0.56      0.56     12344
#            4       0.42      0.45      0.43      3538
#            5       0.09      0.10      0.10       106
#
#     accuracy                           0.65     42354
#    macro avg       0.50      0.51      0.51     42354
# weighted avg       0.65      0.65      0.65     42354
#
# Decision Tree: CrossVal Accuracy Mean: 0.64 and Standard Deviation: 0.01

# %% [markdown]
# ### 5.2 Nearest Neighbors Classifier
# To start off simple, I first ran a basic decision tree classifier. This only generates one tree so it's not computationally intensive, but it's also susceptible to overfitting.

# %%
model = KNeighborsClassifier()
run_model(model, "Nearest Neighbors Classifier")
# Out:
# Model:  Nearest Neighbors Classifier
# Accuracy on Test Set for Nearest Neighbors Classifier = 0.71
#
#               precision    recall  f1-score   support
#
#            1       0.87      0.92      0.89     13304
#            2       0.62      0.68      0.65     13062
#            3       0.65      0.61      0.63     12344
#            4       0.67      0.46      0.54      3538
#            5       0.20      0.01      0.02       106
#
#     accuracy                           0.71     42354
#    macro avg       0.60      0.53      0.55     42354
# weighted avg       0.71      0.71      0.71     42354
#
# Nearest Neighbors Classifier: CrossVal Accuracy Mean: 0.71 and Standard Deviation: 0.01

# %% [markdown]
# ### 5.3 Logisitic Regression

# %%
model = LogisticRegression(multi_class='multinomial' , solver='lbfgs', max_iter=100)
run_model(model, "Logistic Regression")
# Out:
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Model:  Logistic Regression
# Accuracy on Test Set for Logistic Regression = 0.47
#
#               precision    recall  f1-score   support
#
#            1       0.55      0.62      0.58     13304
#            2       0.40      0.31      0.35     13062
#            3       0.45      0.62      0.53     12344
#            4       0.00      0.00      0.00      3538
#            5       0.00      0.00      0.00       106
#
#     accuracy                           0.47     42354
#    macro avg       0.28      0.31      0.29     42354
# weighted avg       0.43      0.47      0.44     42354
#
# Logistic Regression: CrossVal Accuracy Mean: 0.47 and Standard Deviation: 0.00
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:760: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\dazao\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1221: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ### 5.4 Adaboost Classifier

# %%
dt_b = DecisionTreeClassifier(max_depth=1, random_state=42)
model = AdaBoostClassifier(base_estimator=dt_b)
run_model(model, "Adaboost Classifier")
# Out:
# Model:  Adaboost Classifier
# Accuracy on Test Set for Adaboost Classifier = 0.71
#
#               precision    recall  f1-score   support
#
#            1       0.88      0.92      0.90     13304
#            2       0.67      0.60      0.63     13062
#            3       0.61      0.67      0.64     12344
#            4       0.55      0.46      0.50      3538
#            5       0.03      0.09      0.04       106
#
#     accuracy                           0.71     42354
#    macro avg       0.55      0.55      0.54     42354
# weighted avg       0.71      0.71      0.71     42354
#
# Adaboost Classifier: CrossVal Accuracy Mean: 0.70 and Standard Deviation: 0.01

# %% [markdown]
# ### 5.5 Random Forest Classifier

# %%
model = RandomForestClassifier(n_estimators=10)
run_model(model, "Random Forest")
# Out:
# Model:  Random Forest
# Accuracy on Test Set for Random Forest = 0.73
#
#               precision    recall  f1-score   support
#
#            1       0.88      0.92      0.90     13304
#            2       0.64      0.71      0.67     13062
#            3       0.67      0.62      0.64     12344
#            4       0.69      0.44      0.54      3538
#            5       0.25      0.04      0.07       106
#
#     accuracy                           0.73     42354
#    macro avg       0.62      0.55      0.56     42354
# weighted avg       0.72      0.73      0.72     42354
#
# Random Forest: CrossVal Accuracy Mean: 0.73 and Standard Deviation: 0.01

# %% [markdown]
# # 6. Results

# %%
from tabulate import tabulate

print("Classification Results")
rows = list()

for res in results:
    rows.append([res[0], res[1] ])
    
tab = tabulate(rows, headers=['Algorithm', 'Accuracy'], tablefmt='fancy_grid')
print(tab)
# Out:
# Classification Results
# ╒══════════════════════════════╤════════════╕
# │ Algorithm                    │   Accuracy │
# ╞══════════════════════════════╪════════════╡
# │ Decision Tree                │   0.648841 │
# ├──────────────────────────────┼────────────┤
# │ Nearest Neighbors Classifier │   0.713368 │
# ├──────────────────────────────┼────────────┤
# │ Logistic Regression          │   0.47417  │
# ├──────────────────────────────┼────────────┤
# │ Adaboost Classifier          │   0.707773 │
# ├──────────────────────────────┼────────────┤
# │ Random Forest                │   0.727062 │
# ╘══════════════════════════════╧════════════╛

# %% [markdown]
# ### 6.1 Example cases

# %%
cases_mix = cases.sample(frac=1.0, random_state=42).reset_index(drop=True)
cases_mix
cases_drop = cases_mix.drop(['artists', 'name', 'popularity', 'id',  'release_date'], axis=1)
cases_enc = pd.get_dummies(cases_drop, columns=['mode'])

cases_X = cases_enc.drop(['popularity_level', 'mode_0', 'mode_1', 'explicit'], axis=1)
cases_y = cases_mix[['popularity_level']]

cases_pred = pd.DataFrame(results[4][2].predict(cases_X), columns=['popularity_rate'])

# %%
pd.set_option('display.max_rows', df.shape[0]+1)
res = pd.concat([cases_mix, cases_pred], axis=1)
res.iloc[:,[1,11,12,19,20]]
# Out:
#           artists                                               name  \
# 0      The Weeknd                                           Montreal
# 1           Drake                                    6PM In New York
# 2           Drake                                           The Ride
# 3           Drake                                     In My Feelings
# 4    Taylor Swift                              A Place in this World
# 5       Lady Gaga                                           Applause
# 6           Drake                                          Headlines
# 7       Lady Gaga                                            Monster
# 8           Drake                                         Right Hand
# 9      The Weeknd              House Of Balloons / Glass Table Girls
# 10      Lady Gaga                                               A-YO
# 11   Taylor Swift            We Are Never Ever Getting Back Together
# 12   Taylor Swift            We Are Never Ever Getting Back Together
# 13   Taylor Swift                                               Mean
# 14      Lady Gaga                    Eh, Eh (Nothing Else I Can Say)
# 15          Drake                                       Deep Pockets
# 16      Lady Gaga                                          You And I
# 17          Drake                                       Toosie Slide
# 18   Taylor Swift                              Today Was A Fairytale
# 19   Taylor Swift                                      I Know Places
# 20          Drake                                         Still Here
# 21   Taylor Swift                                       Cruel Summer
# 22      Lady Gaga                                   Perfect Illusion
# 23      Lady Gaga                                           Applause
# 24          Drake                             Summers Over Interlude
# 25   Taylor Swift                                           Innocent
# 26   Taylor Swift                                   Out Of The Woods
# 27      Lady Gaga                                          Donatella
# 28          Drake                                      Sandra’s Rose
# 29   Taylor Swift                                     Mine - POP Mix
# 30   Taylor Swift                                         London Boy
# 31          Drake                              Keep The Family Close
# 32          Drake                                           Survival
# 33          Drake                                           The Calm
# 34     The Weeknd                                        Alone Again
# 35      Lady Gaga                                    I Like It Rough
# 36          Drake                                             Energy
# 37          Drake                                       Toosie Slide
# 38          Drake                                        Emotionless
# 39     The Weeknd              House Of Balloons / Glass Table Girls
# 40          Drake                                     Find Your Love
# 41   Taylor Swift                                          Afterglow
# 42   Taylor Swift                         The Other Side Of The Door
# 43     The Weeknd                        The Party & The After Party
# 44      Lady Gaga                                          Summerboy
# 45     The Weeknd                                            Outside
# 46   Taylor Swift                                          Bad Blood
# 47     The Weeknd                                   Call Out My Name
# 48     The Weeknd                                Belong To The World
# 49          Drake                                         Time Flies
# 50          Drake                                     Furthest Thing
# 51     The Weeknd                                      Ordinary Life
# 52   Taylor Swift                                        Holy Ground
# 53          Drake                                    Best I Ever Had
# 54          Drake                                       The Language
# 55          Drake                                Behind Barz - Bonus
# 56          Drake                                               Fear
# 57          Drake                                         Free Smoke
# 58     The Weeknd                                      What You Need
# 59     The Weeknd                                               D.D.
# 60   Taylor Swift                                          Speak Now
# 61   Taylor Swift                                            Haunted
# 62   Taylor Swift                                Better Than Revenge
# 63   Taylor Swift                                               Mine
# 64   Taylor Swift        Only The Young - Featured in Miss Americana
# 65          Drake                                    Best I Ever Had
# 66   Taylor Swift                                     State Of Grace
# 67     The Weeknd                                Heaven Or Las Vegas
# 68     The Weeknd                                       Twenty Eight
# 69   Taylor Swift                                                Red
# 70          Drake                                      Now & Forever
# 71     The Weeknd                                     Escape From LA
# 72          Drake                                         The Motion
# 73      Lady Gaga                                    Marry The Night
# 74          Drake                                         U With Me?
# 75   Taylor Swift                                                 22
# 76   Taylor Swift                                 You Belong With Me
# 77   Taylor Swift                         It’s Nice To Have A Friend
# 78      Lady Gaga                                              Gypsy
# 79          Drake                                  Houstatlantavegas
# 80   Taylor Swift                                              Style
# 81          Drake                                    Wu-Tang Forever
# 82     The Weeknd                                    Hardest To Love
# 83   Taylor Swift                                        Hey Stephen
# 84      Lady Gaga                                         Poker Face
# 85      Lady Gaga                                              Swine
# 86   Taylor Swift                                         Wonderland
# 87   Taylor Swift                                    You Are In Love
# 88          Drake                           Nothings Into Somethings
# 89   Taylor Swift                                         Sparks Fly
# 90   Taylor Swift                                          Long Live
# 91      Lady Gaga                                      Diamond Heart
# 92      Lady Gaga                                         John Wayne
# 93          Drake                                              Jaded
# 94   Taylor Swift                  State Of Grace - Acoustic Version
# 95   Taylor Swift                                    Picture To Burn
# 96      Lady Gaga                                          Paparazzi
# 97   Taylor Swift                         All You Had To Do Was Stay
# 98     The Weeknd                        Final Lullaby - Bonus Track
# 99     The Weeknd                                  Until I Bleed Out
# 100  Taylor Swift                         Haunted - Acoustic Version
# 101     Lady Gaga                                              Venus
# 102  Taylor Swift                                              Lover
# 103    The Weeknd                                       Wasted Times
# 104  Taylor Swift                                              Style
# 105  Taylor Swift                                      New Romantics
# 106    The Weeknd                                        The Knowing
# 107         Drake                                     Worst Behavior
# 108         Drake                                  Weston Road Flows
# 109     Lady Gaga                                              Alice
# 110    The Weeknd                                          Heartless
# 111         Drake                                             Star67
# 112         Drake                                       Marvins Room
# 113  Taylor Swift                                       Girl At Home
# 114    The Weeknd                                       Professional
# 115  Taylor Swift             Miss Americana & The Heartbreak Prince
# 116         Drake                                     Worst Behavior
# 117    The Weeknd                                  Life Of The Party
# 118  Taylor Swift                                        Blank Space
# 119         Drake                                          Fake Love
# 120         Drake                                     The Resistance
# 121  Taylor Swift                                   Forever & Always
# 122    The Weeknd                                            Rockin’
# 123  Taylor Swift                                Welcome To New York
# 124    The Weeknd                                     A Lonely Night
# 125    The Weeknd                                  Tears In The Rain
# 126  Taylor Swift                                  Should've Said No
# 127         Drake                                        Childs Play
# 128    The Weeknd                                           Too Late
# 129  Taylor Swift                      I'm Only Me When I'm With You
# 130  Taylor Swift                                   You're Not Sorry
# 131     Lady Gaga                                            ScheiBe
# 132         Drake                                    Congratulations
# 133         Drake                                        You & The 6
# 134         Drake                                            Connect
# 135         Drake                                            Nonstop
# 136  Taylor Swift                                 You Belong With Me
# 137  Taylor Swift                                     Jump Then Fall
# 138  Taylor Swift                                The Way I Loved You
# 139     Lady Gaga                                            Scheiße
# 140  Taylor Swift                                         Love Story
# 141  Taylor Swift                                   I Wish You Would
# 142  Taylor Swift                                          This Love
# 143         Drake                                         No Tellin'
# 144  Taylor Swift                                        Untouchable
# 145  Taylor Swift                                               Mine
# 146  Taylor Swift                                          Dear John
# 147         Drake                                       How Bout Now
# 148    The Weeknd                                         Wanderlust
# 149    The Weeknd                                          Kiss Land
# 150         Drake                            Started From the Bottom
# 151         Drake                                             Own It
# 152  Taylor Swift                                          Long Live
# 153         Drake                                      Know Yourself
# 154  Taylor Swift                                          Speak Now
# 155    The Weeknd                                         Initiation
# 156    The Weeknd                                        The Knowing
# 157  Taylor Swift                                    Cornelia Street
# 158    The Weeknd                           Missed You - Bonus Track
# 159  Taylor Swift                                           Daylight
# 160  Taylor Swift                                              Clean
# 161     Lady Gaga                                           LoveGame
# 162  Taylor Swift                                              Dress
# 163  Taylor Swift                                           Superman
# 164         Drake                                       Thank Me Now
# 165     Lady Gaga                                  Heavy Metal Lover
# 166         Drake                                     Find Your Love
# 167         Drake                                     Doing It Wrong
# 168  Taylor Swift                                     Don’t Blame Me
# 169     Lady Gaga                             Beautiful, Dirty, Rich
# 170         Drake                                        8 Out Of 10
# 171    The Weeknd                                        After Hours
# 172  Taylor Swift                              You Need To Calm Down
# 173  Taylor Swift                                           Our Song
# 174    The Weeknd                                             Try Me
# 175  Taylor Swift                                        White Horse
# 176  Taylor Swift                                   You're Not Sorry
# 177         Drake                                             Legend
# 178         Drake                                       Back To Back
# 179  Taylor Swift                                        The Outside
# 180         Drake                                               Peak
# 181         Drake                                              Signs
# 182     Lady Gaga                                              Teeth
# 183  Taylor Swift                                                 22
# 184    The Weeknd                                        Die For You
# 185  Taylor Swift                                        Cold As You
# 186    The Weeknd                                    The Birds Pt. 1
# 187  Taylor Swift                                        Hey Stephen
# 188     Lady Gaga                                  Government Hooker
# 189         Drake                                  Can’t Take A Joke
# 190  Taylor Swift        Teardrops On My Guitar - Radio Single Remix
# 191     Lady Gaga                                         Brown Eyes
# 192         Drake                                    Best I Ever Had
# 193         Drake                                         Still Here
# 194  Taylor Swift                                       Shake It Off
# 195    The Weeknd                                           The Town
# 196         Drake                                           Practice
# 197  Taylor Swift                                       Shake It Off
# 198  Taylor Swift                                Welcome To New York
# 199    The Weeknd                                    Save Your Tears
# 200         Drake                                              Views
# 201  Taylor Swift                Back To December - Acoustic Version
# 202  Taylor Swift                                            Fifteen
# 203     Lady Gaga                                           LoveGame
# 204         Drake                                Show Me A Good Time
# 205         Drake                                          Headlines
# 206  Taylor Swift                                           Our Song
# 207  Taylor Swift                           I Knew You Were Trouble.
# 208    The Weeknd                                             Pretty
# 209    The Weeknd                                Nothing Without You
# 210  Taylor Swift                                           Delicate
# 211  Taylor Swift                                                Red
# 212     Lady Gaga                                                911
# 213  Taylor Swift                   Forever & Always - Piano Version
# 214     Lady Gaga                                    Marry The Night
# 215     Lady Gaga                               So Happy I Could Die
# 216         Drake                                        Shot For Me
# 217     Lady Gaga                              Til It Happens To You
# 218    The Weeknd                                      Rolling Stone
# 219  Taylor Swift                                    The Story Of Us
# 220  Taylor Swift                                      Never Grow Up
# 221         Drake                                       The Language
# 222  Taylor Swift                                          Eyes Open
# 223    The Weeknd                                    The Birds Pt. 1
# 224    The Weeknd                                        True Colors
# 225  Taylor Swift                                   Forever & Always
# 226         Drake                                            Karaoke
# 227  Taylor Swift                                     Wildest Dreams
# 228  Taylor Swift                                Better Than Revenge
# 229     Lady Gaga                             Beautiful, Dirty, Rich
# 230    The Weeknd                                       Wicked Games
# 231     Lady Gaga                                          Paparazzi
# 232    The Weeknd                                    Blinding Lights
# 233  Taylor Swift                                        Begin Again
# 234  Taylor Swift                                  Should've Said No
# 235  Taylor Swift                         All You Had To Do Was Stay
# 236    The Weeknd                                           Thursday
# 237     Lady Gaga                                           The Fame
# 238     Lady Gaga                                           MANiCURE
# 239     Lady Gaga                                               Aura
# 240  Taylor Swift                 Today Was A Fairytale - US Version
# 241  Taylor Swift                                        Begin Again
# 242         Drake                                             Jungle
# 243    The Weeknd                                          Privilege
# 244  Taylor Swift                                          Last Kiss
# 245     Lady Gaga                                         1000 Doves
# 246     Lady Gaga                                          You And I
# 247    The Weeknd                                              Faith
# 248         Drake                                       Trust Issues
# 249     Lady Gaga                        Always Remember Us This Way
# 250  Taylor Swift                                   Back To December
# 251         Drake                                Behind Barz - Bonus
# 252  Taylor Swift                                    Picture To Burn
# 253         Drake                            Started From the Bottom
# 254    The Weeknd                                        Lonely Star
# 255    The Weeknd                                        Coming Down
# 256     Lady Gaga                                         Poker Face
# 257         Drake                                        Gyalchester
# 258    The Weeknd                                      Rolling Stone
# 259         Drake                                               Over
# 260  Taylor Swift                      Red - Original Demo Recording
# 261  Taylor Swift         Death By A Thousand Cuts - Live From Paris
# 262     Lady Gaga                                              Judas
# 263  Taylor Swift                                   I Think He Knows
# 264  Taylor Swift              Treacherous - Original Demo Recording
# 265         Drake                                     Summer Sixteen
# 266    The Weeknd                                               D.D.
# 267  Taylor Swift                                         Tim McGraw
# 268  Taylor Swift                                       All Too Well
# 269  Taylor Swift                                                 22
# 270  Taylor Swift                                       The Best Day
# 271    The Weeknd                                        Love To Lay
# 272  Taylor Swift                                        I Almost Do
# 273  Taylor Swift        Teardrops On My Guitar - Radio Single Remix
# 274    The Weeknd                                    Love In The Sky
# 275         Drake                                           10 Bands
# 276     Lady Gaga                                           Fashion!
# 277  Taylor Swift                          Mary's Song (Oh My My My)
# 278  Taylor Swift                          I Forgot That You Existed
# 279     Lady Gaga                                               Hair
# 280         Drake                                      Teenage Fever
# 281    The Weeknd                                              Faith
# 282    The Weeknd                                        The Morning
# 283         Drake                                          I'm Upset
# 284    The Weeknd                                          Attention
# 285  Taylor Swift                         Tied Together with a Smile
# 286  Taylor Swift               Teardrops on My Guitar - Pop Version
# 287  Taylor Swift                                          Invisible
# 288    The Weeknd                                     Scared To Live
# 289  Taylor Swift                                        Getaway Car
# 290     Lady Gaga                                              Teeth
# 291  Taylor Swift                                     Wildest Dreams
# 292    The Weeknd                                       In Your Eyes
# 293     Lady Gaga                                            Monster
# 294     Lady Gaga                                         Speechless
# 295     Lady Gaga                                          Paparazzi
# 296    The Weeknd                                      High For This
# 297  Taylor Swift                                       Shake It Off
# 298  Taylor Swift                                         Love Story
# 299    The Weeknd                                    The Birds Pt. 2
# 300  Taylor Swift                                        Blank Space
# 301     Lady Gaga                                          Americano
# 302     Lady Gaga                                  The Edge Of Glory
# 303  Taylor Swift                           Look What You Made Me Do
# 304  Taylor Swift                                         Love Story
# 305     Lady Gaga           I'll Never Love Again - Extended Version
# 306     Lady Gaga                                        Bloody Mary
# 307  Taylor Swift                               How You Get The Girl
# 308     Lady Gaga                                      Born This Way
# 309     Lady Gaga                                           The Cure
# 310  Taylor Swift                                     Stay Beautiful
# 311         Drake                              Can't Have Everything
# 312  Taylor Swift                                   ...Ready For It?
# 313     Lady Gaga                    Eh, Eh (Nothing Else I Can Say)
# 314         Drake                                   Cece's Interlude
# 315  Taylor Swift                                        Paper Rings
# 316         Drake                                         Redemption
# 317  Taylor Swift                                         Tim McGraw
# 318         Drake                                          Controlla
# 319     Lady Gaga                                       Sexxx Dreams
# 320    The Weeknd                                               Next
# 321         Drake                                            Elevate
# 322    The Weeknd                                        False Alarm
# 323         Drake                                30 for 30 Freestyle
# 324         Drake          Cameras / Good Ones Go Interlude - Medley
# 325  Taylor Swift                                            Fifteen
# 326  Taylor Swift                           I Knew You Were Trouble.
# 327    The Weeknd                        The Party & The After Party
# 328  Taylor Swift                                          SuperStar
# 329         Drake                                That’s How You Feel
# 330         Drake                                       Passionfruit
# 331    The Weeknd                                           Too Late
# 332         Drake                                              6 Man
# 333  Taylor Swift                                          Enchanted
# 334  Taylor Swift                                            The Man
# 335  Taylor Swift                                                Red
# 336  Taylor Swift              This Is Why We Can't Have Nice Things
# 337         Drake                                  Over My Dead Body
# 338    The Weeknd                     Nothing Compares - Bonus Track
# 339  Taylor Swift                                        Tell Me Why
# 340         Drake                                       Toosie Slide
# 341    The Weeknd                                      What You Need
# 342     Lady Gaga                               So Happy I Could Die
# 343  Taylor Swift                                          Bad Blood
# 344         Drake                                        Childs Play
# 345    The Weeknd                                            Secrets
# 346  Taylor Swift                                             Change
# 347  Taylor Swift                                           Innocent
# 348    The Weeknd                                        Die For You
# 349     Lady Gaga                                     Boys Boys Boys
# 350  Taylor Swift                           Look What You Made Me Do
# 351     Lady Gaga                                        Stupid Love
# 352     Lady Gaga                                             ARTPOP
# 353    The Weeknd                                      Party Monster
# 354         Drake                                         God's Plan
# 355     Lady Gaga                                             Joanne
# 356     Lady Gaga                                       Chromatica I
# 357    The Weeknd                                           Reminder
# 358    The Weeknd                                       Twenty Eight
# 359         Drake                                             Own It
# 360  Taylor Swift                                       The Best Day
# 361  Taylor Swift                                   Back To December
# 362  Taylor Swift                                           Gorgeous
# 363  Taylor Swift            We Are Never Ever Getting Back Together
# 364  Taylor Swift                              Come In With The Rain
# 365         Drake                                          Blue Tint
# 366  Taylor Swift                                If This Was A Movie
# 367     Lady Gaga                                         Free Woman
# 368         Drake                                           Mob Ties
# 369    The Weeknd                                     Escape From LA
# 370         Drake                            0 To 100 / The Catch Up
# 371  Taylor Swift                                Come Back...Be Here
# 372    The Weeknd                                        Lonely Star
# 373    The Weeknd                                         Adaptation
# 374  Taylor Swift                                   Back To December
# 375     Lady Gaga                        Always Remember Us This Way
# 376     Lady Gaga                                              Judas
# 377     Lady Gaga                                  The Edge Of Glory
# 378         Drake                                          Pop Style
# 379         Drake                                            Connect
# 380  Taylor Swift                                     New Year’s Day
# 381  Taylor Swift                                The Way I Loved You
# 382    The Weeknd                     Till Dawn (Here Comes The Sun)
# 383     Lady Gaga                                      Born This Way
# 384     Lady Gaga                                          Americano
# 385     Lady Gaga                                         Poker Face
# 386  Taylor Swift                               Sad Beautiful Tragic
# 387  Taylor Swift                              Call It What You Want
# 388         Drake                                          Controlla
# 389  Taylor Swift                                        Blank Space
# 390         Drake                                               Hype
# 391         Drake                                     Tuscan Leather
# 392     Lady Gaga                                  Dance In The Dark
# 393  Taylor Swift                                          Enchanted
# 394  Taylor Swift                                              Style
# 395         Drake                                       Feel No Ways
# 396         Drake                                             Losses
# 397  Taylor Swift                                  The Moment I Knew
# 398         Drake                                          Come Thru
# 399  Taylor Swift                               How You Get The Girl
# 400  Taylor Swift                                      The Lucky One
# 401     Lady Gaga                                          Alejandro
# 402         Drake                                    Wu-Tang Forever
# 403  Taylor Swift                                               Ours
# 404    The Weeknd                                      High For This
# 405  Taylor Swift                           I Knew You Were Trouble.
# 406    The Weeknd                                       Wicked Games
# 407         Drake                                      Fire & Desire
# 408    The Weeknd                        Repeat After Me (Interlude)
# 409         Drake                                      November 18th
# 410  Taylor Swift                                         Sparks Fly
# 411         Drake                                     Do Not Disturb
# 412         Drake                                    Jorja Interlude
# 413  Taylor Swift                                             Change
# 414  Taylor Swift                                        Treacherous
# 415  Taylor Swift                                        Tell Me Why
# 416  Taylor Swift                                          False God
# 417    The Weeknd                                               Gone
# 418  Taylor Swift                                   King Of My Heart
# 419    The Weeknd                                  Echoes Of Silence
# 420    The Weeknd                                        Coming Down
# 421    The Weeknd  Earned It (Fifty Shades Of Grey) - From The "F...
# 422     Lady Gaga                                      Paper Gangsta
# 423         Drake                                      Lust For Life
# 424  Taylor Swift                                         The Archer
# 425    The Weeknd                                        After Hours
# 426  Taylor Swift                                    The Story Of Us
# 427  Taylor Swift                                      Never Grow Up
# 428     Lady Gaga                                        Money Honey
# 429     Lady Gaga                                        Bloody Mary
# 430         Drake                                          Brand New
# 431         Drake                                 Under Ground Kings
# 432    The Weeknd                                           The Fall
# 433         Drake                                     Furthest Thing
# 434         Drake                                       Summer Games
# 435    The Weeknd                                       Wicked Games
# 436    The Weeknd                                         Loft Music
# 437  Taylor Swift                                     Wildest Dreams
# 438         Drake                                            Finesse
# 439         Drake                                            Madonna
# 440     Lady Gaga                                     Boys Boys Boys
# 441  Taylor Swift                                          Dear John
# 442    The Weeknd                                      XO / The Host
# 443         Drake                                              6 God
# 444         Drake                              Look What You've Done
# 445     Lady Gaga                                         Speechless
# 446     Lady Gaga                        Always Remember Us This Way
# 447         Drake                                               Blem
# 448  Taylor Swift                                          Starlight
# 449         Drake                                      Nice For What
# 450         Drake                                    Say What's Real
# 451     Lady Gaga                                          Alejandro
# 452  Taylor Swift                        Dancing With Our Hands Tied
# 453  Taylor Swift                                        White Horse
# 454         Drake                                      Hotline Bling
# 455  Taylor Swift                                       All Too Well
# 456  Taylor Swift                                      I Know Places
# 457  Taylor Swift                                          Last Kiss
# 458  Taylor Swift                                            Crazier
# 459  Taylor Swift                                   Out Of The Woods
# 460  Taylor Swift                                   I Wish You Would
# 461    The Weeknd                                            Valerie
# 462         Drake                                                  9
# 463    The Weeknd                                        The Morning
# 464     Lady Gaga                                             G.U.Y.
# 465         Drake                                  Sooner Than Later
# 466         Drake                                               Over
# 467     Lady Gaga                                      Born This Way
# 468    The Weeknd                                    Hardest To Love
# 469  Taylor Swift                                            Haunted
# 470         Drake                                Show Me A Good Time
# 471    The Weeknd                                     Six Feet Under
# 472  Taylor Swift                                               Mean
# 473  Taylor Swift                                 You Belong With Me
# 474    The Weeknd                                       In Your Eyes
# 475     Lady Gaga                                        Bad Romance
# 476  Taylor Swift                                I Did Something Bad
# 477  Taylor Swift                                      So It Goes...
# 478  Taylor Swift                                           Fearless
# 479         Drake                                      Madiba Riddim
# 480  Taylor Swift                                              Clean
# 481    The Weeknd                                          Snowchild
# 482     Lady Gaga                                    Million Reasons
# 483  Taylor Swift                             A Perfectly Good Heart
# 484         Drake                                          Headlines
# 485  Taylor Swift                  Cornelia Street - Live From Paris
# 486  Taylor Swift                                          This Love
# 487  Taylor Swift                                           Fearless
# 488    The Weeknd                                         Loft Music
# 489    The Weeknd                                    Blinding Lights
# 490         Drake                                       Marvins Room
# 491  Taylor Swift                                     Stay Stay Stay
# 492  Taylor Swift                           Death By A Thousand Cuts
# 493  Taylor Swift                                       All Too Well
#
#      popularity  popularity_level  popularity_rate
# 0            56                 3                3
# 1            55                 3                3
# 2            55                 3                3
# 3            81                 5                4
# 4            49                 3                3
# 5            72                 4                3
# 6            72                 4                3
# 7            44                 3                3
# 8            62                 4                4
# 9            48                 3                3
# 10           60                 3                3
# 11           64                 4                3
# 12           58                 3                3
# 13           63                 4                4
# 14           48                 3                3
# 15           74                 4                4
# 16           49                 3                3
# 17           69                 4                4
# 18           52                 3                3
# 19           51                 3                3
# 20           63                 4                3
# 21           75                 4                4
# 22           66                 4                3
# 23           55                 3                3
# 24           58                 3                4
# 25           43                 3                3
# 26           55                 3                3
# 27           60                 3                3
# 28           64                 4                4
# 29           45                 3                3
# 30           71                 4                4
# 31           58                 3                3
# 32           61                 4                4
# 33           48                 3                3
# 34           75                 4                4
# 35           44                 3                3
# 36           71                 4                4
# 37           87                 5                4
# 38           67                 4                4
# 39           61                 4                3
# 40           60                 3                3
# 41           71                 4                4
# 42           44                 3                3
# 43           59                 3                3
# 44           46                 3                3
# 45           53                 3                3
# 46           52                 3                3
# 47           82                 5                4
# 48           51                 3                3
# 49           79                 4                4
# 50           51                 3                3
# 51           66                 4                4
# 52           52                 3                3
# 53           47                 3                3
# 54           49                 3                3
# 55           72                 4                4
# 56           50                 3                3
# 57           64                 4                4
# 58           65                 4                3
# 59           63                 4                3
# 60           50                 3                3
# 61           45                 3                3
# 62           48                 3                3
# 63           54                 3                3
# 64           73                 4                4
# 65           68                 4                3
# 66           53                 3                3
# 67           52                 3                3
# 68           61                 4                3
# 69           58                 3                3
# 70           58                 3                3
# 71           65                 4                4
# 72           64                 4                4
# 73           47                 3                3
# 74           60                 3                3
# 75           70                 4                4
# 76           56                 3                3
# 77           66                 4                3
# 78           55                 3                3
# 79           59                 3                3
# 80           56                 3                3
# 81           50                 3                3
# 82           66                 4                4
# 83           46                 3                3
# 84           55                 3                3
# 85           54                 3                3
# 86           53                 3                3
# 87           54                 3                3
# 88           59                 3                4
# 89           55                 3                3
# 90           52                 3                3
# 91           60                 3                4
# 92           63                 4                3
# 93           66                 4                4
# 94           48                 3                3
# 95           57                 3                3
# 96           49                 3                3
# 97           51                 3                3
# 98           71                 4                4
# 99           72                 4                4
# 100          45                 3                3
# 101          63                 4                4
# 102          81                 5                4
# 103          72                 4                4
# 104          56                 3                3
# 105          57                 3                3
# 106          56                 3                3
# 107          50                 3                3
# 108          59                 3                3
# 109          82                 5                4
# 110          84                 5                4
# 111          60                 3                4
# 112          74                 4                3
# 113          47                 3                3
# 114          59                 3                3
# 115          71                 4                4
# 116          57                 3                3
# 117          54                 3                3
# 118          62                 4                3
# 119          75                 4                4
# 120          49                 3                3
# 121          47                 3                3
# 122          68                 4                4
# 123          51                 3                4
# 124          67                 4                3
# 125          52                 3                3
# 126          52                 3                3
# 127          52                 3                4
# 128          75                 4                4
# 129          50                 3                3
# 130          51                 3                3
# 131          47                 3                3
# 132          57                 3                3
# 133          56                 3                3
# 134          49                 3                3
# 135          81                 5                4
# 136          70                 4                3
# 137          47                 3                3
# 138          46                 3                3
# 139          44                 3                4
# 140          68                 4                3
# 141          51                 3                3
# 142          51                 3                3
# 143          61                 4                3
# 144          46                 3                3
# 145          62                 4                3
# 146          46                 3                3
# 147          64                 4                4
# 148          53                 3                3
# 149          54                 3                3
# 150          51                 3                3
# 151          54                 3                3
# 152          47                 3                3
# 153          68                 4                3
# 154          52                 3                3
# 155          52                 3                3
# 156          44                 3                3
# 157          71                 4                4
# 158          74                 4                4
# 159          69                 4                4
# 160          55                 3                3
# 161          62                 4                3
# 162          64                 4                4
# 163          46                 3                3
# 164          48                 3                3
# 165          44                 3                3
# 166          56                 3                3
# 167          69                 4                3
# 168          66                 4                4
# 169          46                 3                3
# 170          62                 4                3
# 171          84                 5                4
# 172          83                 5                4
# 173          66                 4                3
# 174          72                 4                4
# 175          48                 3                3
# 176          46                 3                3
# 177          68                 4                3
# 178          67                 4                3
# 179          46                 3                3
# 180          61                 4                4
# 181          69                 4                4
# 182          53                 3                3
# 183          60                 3                4
# 184          77                 4                4
# 185          48                 3                3
# 186          55                 3                3
# 187          52                 3                3
# 188          44                 3                3
# 189          67                 4                4
# 190          62                 4                3
# 191          44                 3                3
# 192          70                 4                3
# 193          59                 3                3
# 194          63                 4                3
# 195          51                 3                3
# 196          61                 4                3
# 197          70                 4                3
# 198          59                 3                3
# 199          81                 5                4
# 200          58                 3                3
# 201          54                 3                3
# 202          48                 3                3
# 203          53                 3                3
# 204          47                 3                3
# 205          53                 3                3
# 206          62                 4                3
# 207          58                 3                3
# 208          59                 3                3
# 209          65                 4                3
# 210          77                 4                4
# 211          58                 3                3
# 212          83                 5                4
# 213          48                 3                3
# 214          55                 3                3
# 215          54                 3                3
# 216          64                 4                3
# 217          58                 3                3
# 218          56                 3                3
# 219          56                 3                3
# 220          53                 3                3
# 221          56                 3                3
# 222          50                 3                3
# 223          43                 3                3
# 224          69                 4                4
# 225          52                 3                3
# 226          46                 3                3
# 227          55                 3                3
# 228          52                 3                3
# 229          52                 3                3
# 230          73                 4                3
# 231          67                 4                3
# 232         100                 5                4
# 233          52                 3                3
# 234          58                 3                3
# 235          58                 3                3
# 236          53                 3                3
# 237          51                 3                3
# 238          54                 3                3
# 239          56                 3                3
# 240          45                 3                3
# 241          55                 3                3
# 242          70                 4                4
# 243          68                 4                3
# 244          47                 3                3
# 245          79                 4                4
# 246          61                 4                3
# 247          75                 4                4
# 248          68                 4                4
# 249          74                 4                4
# 250          61                 4                3
# 251          68                 4                4
# 252          61                 4                3
# 253          66                 4                3
# 254          55                 3                3
# 255          56                 3                3
# 256          72                 4                3
# 257          69                 4                4
# 258          43                 3                3
# 259          58                 3                3
# 260          45                 3                3
# 261          65                 4                4
# 262          60                 3                3
# 263          71                 4                4
# 264          45                 3                3
# 265          58                 3                4
# 266          43                 3                3
# 267          60                 3                3
# 268          61                 4                3
# 269          58                 3                4
# 270          50                 3                3
# 271          65                 4                4
# 272          53                 3                3
# 273          60                 3                3
# 274          59                 3                3
# 275          64                 4                4
# 276          54                 3                3
# 277          50                 3                3
# 278          77                 4                4
# 279          49                 3                3
# 280          74                 4                4
# 281          65                 4                4
# 282          51                 3                3
# 283          72                 4                4
# 284          66                 4                4
# 285          47                 3                3
# 286          48                 3                3
# 287          46                 3                3
# 288          76                 4                4
# 289          69                 4                3
# 290          51                 3                4
# 291          53                 3                3
# 292          91                 5                4
# 293          58                 3                3
# 294          52                 3                3
# 295          55                 3                3
# 296          48                 3                3
# 297          57                 3                3
# 298          54                 3                3
# 299          54                 3                3
# 300          71                 4                3
# 301          43                 3                3
# 302          63                 4                3
# 303          74                 4                4
# 304          76                 4                3
# 305          70                 4                4
# 306          43                 3                3
# 307          53                 3                3
# 308           0                 1                4
# 309          70                 4                4
# 310          49                 3                3
# 311          59                 3                4
# 312          71                 4                3
# 313          51                 3                3
# 314          43                 3                3
# 315          72                 4                4
# 316          64                 4                4
# 317          55                 3                3
# 318          60                 3                4
# 319          58                 3                4
# 320          55                 3                3
# 321          64                 4                4
# 322          69                 4                3
# 323          54                 3                3
# 324          58                 3                3
# 325          59                 3                3
# 326          66                 4                3
# 327          47                 3                3
# 328          44                 3                3
# 329          65                 4                4
# 330          80                 4                4
# 331          65                 4                4
# 332          60                 3                3
# 333          52                 3                3
# 334          82                 5                4
# 335          64                 4                3
# 336          64                 4                3
# 337          60                 3                3
# 338          74                 4                4
# 339          48                 3                3
# 340          95                 5                4
# 341          47                 3                3
# 342          50                 3                3
# 343          65                 4                3
# 344          65                 4                4
# 345          71                 4                3
# 346          46                 3                3
# 347          47                 3                3
# 348          66                 4                4
# 349          49                 3                3
# 350          65                 4                4
# 351          84                 5                4
# 352          61                 4                3
# 353          73                 4                4
# 354          84                 5                4
# 355          62                 4                3
# 356          78                 4                4
# 357          73                 4                3
# 358          46                 3                3
# 359          48                 3                3
# 360          44                 3                3
# 361          55                 3                3
# 362          70                 4                4
# 363          75                 4                3
# 364          46                 3                3
# 365          64                 4                4
# 366          50                 3                3
# 367          82                 5                4
# 368          73                 4                4
# 369          76                 4                4
# 370          70                 4                3
# 371          51                 3                3
# 372          43                 3                3
# 373          52                 3                3
# 374          43                 3                3
# 375          60                 3                4
# 376          50                 3                3
# 377          48                 3                3
# 378          64                 4                3
# 379          51                 3                3
# 380          63                 4                3
# 381          51                 3                3
# 382          53                 3                3
# 383          68                 4                3
# 384          47                 3                3
# 385          49                 3                3
# 386          50                 3                3
# 387          68                 4                4
# 388          72                 4                4
# 389          58                 3                3
# 390          61                 4                3
# 391          51                 3                3
# 392          57                 3                3
# 393          58                 3                3
# 394          64                 4                3
# 395          70                 4                3
# 396          73                 4                4
# 397          50                 3                3
# 398          59                 3                3
# 399          52                 3                3
# 400          50                 3                3
# 401          66                 4                3
# 402          55                 3                3
# 403          54                 3                3
# 404          68                 4                3
# 405          77                 4                3
# 406          47                 3                3
# 407          69                 4                4
# 408          72                 4                4
# 409          61                 4                3
# 410          52                 3                3
# 411          71                 4                4
# 412          61                 4                4
# 413          43                 3                3
# 414          52                 3                3
# 415          44                 3                3
# 416          69                 4                4
# 417          53                 3                3
# 418          65                 4                4
# 419          56                 3                3
# 420          45                 3                3
# 421          78                 4                3
# 422          46                 3                3
# 423          58                 3                3
# 424          73                 4                4
# 425          66                 4                4
# 426          52                 3                3
# 427          47                 3                3
# 428          46                 3                3
# 429          53                 3                3
# 430          57                 3                3
# 431          59                 3                3
# 432          53                 3                3
# 433          57                 3                3
# 434          62                 4                4
# 435          52                 3                3
# 436          63                 4                3
# 437          69                 4                3
# 438          71                 4                4
# 439          57                 3                3
# 440          46                 3                3
# 441          53                 3                3
# 442          54                 3                3
# 443          62                 4                3
# 444          58                 3                3
# 445          55                 3                3
# 446          79                 4                4
# 447          65                 4                4
# 448          50                 3                3
# 449          80                 4                4
# 450          49                 3                3
# 451          63                 4                3
# 452          65                 4                4
# 453          58                 3                3
# 454          77                 4                4
# 455          47                 3                3
# 456          50                 3                3
# 457          51                 3                3
# 458          59                 3                3
# 459          60                 3                3
# 460          51                 3                4
# 461          61                 4                3
# 462          60                 3                3
# 463          70                 4                3
# 464          66                 4                3
# 465          50                 3                3
# 466          63                 4                3
# 467          52                 3                3
# 468          76                 4                4
# 469          49                 3                3
# 470          51                 3                3
# 471          68                 4                3
# 472          53                 3                4
# 473          68                 4                3
# 474          66                 4                4
# 475          80                 4                3
# 476          69                 4                4
# 477          62                 4                4
# 478          48                 3                3
# 479          63                 4                4
# 480          52                 3                3
# 481          74                 4                4
# 482          77                 4                4
# 483          44                 3                3
# 484          42                 3                3
# 485          70                 4                4
# 486          51                 3                3
# 487          58                 3                3
# 488          46                 3                3
# 489          67                 4                4
# 490          56                 3                3
# 491          53                 3                3
# 492          70                 4                4
# 493          53                 3                3
